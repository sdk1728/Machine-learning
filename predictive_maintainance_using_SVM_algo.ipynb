# %%
import pandas as pd
import numpy as np

# %%
df1=pd.read_csv('predictive_maintenance.csv')
df1.head()
# Out:
#    UDI Product ID Type  Air temperature [K]  Process temperature [K]  \
# 0    1     M14860    M                298.1                    308.6
# 1    2     L47181    L                298.2                    308.7
# 2    3     L47182    L                298.1                    308.5
# 3    4     L47183    L                298.2                    308.6
# 4    5     L47184    L                298.2                    308.7
#
#    Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target Failure Type
# 0                    1551         42.8                0       0   No Failure
# 1                    1408         46.3                3       0   No Failure
# 2                    1498         49.4                5       0   No Failure
# 3                    1433         39.5                7       0   No Failure
# 4                    1408         40.0                9       0   No Failure

# %%
df1.describe()
# Out:
#                UDI  Air temperature [K]  Process temperature [K]  \
# count  10000.00000         10000.000000             10000.000000
# mean    5000.50000           300.004930               310.005560
# std     2886.89568             2.000259                 1.483734
# min        1.00000           295.300000               305.700000
# 25%     2500.75000           298.300000               308.800000
# 50%     5000.50000           300.100000               310.100000
# 75%     7500.25000           301.500000               311.100000
# max    10000.00000           304.500000               313.800000
#
#        Rotational speed [rpm]   Torque [Nm]  Tool wear [min]        Target
# count            10000.000000  10000.000000     10000.000000  10000.000000
# mean              1538.776100     39.986910       107.951000      0.033900
# std                179.284096      9.968934        63.654147      0.180981
# min               1168.000000      3.800000         0.000000      0.000000
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   UDI                      10000 non-null  int64
#  1   Product ID               10000 non-null  object
#  2   Type                     10000 non-null  object
#  3   Air temperature [K]      10000 non-null  float64
#  4   Process temperature [K]  10000 non-null  float64
#  5   Rotational speed [rpm]   10000 non-null  int64
#  6   Torque [Nm]              10000 non-null  float64
#  7   Tool wear [min]          10000 non-null  int64
#  8   Target                   10000 non-null  int64
#  9   Failure Type             10000 non-null  object
# dtypes: float64(3), int64(4), object(3)
# memory usage: 781.4+ KB

# %%
df1.isna().sum()
# Out:
# UDI                        0
# Product ID                 0
# Type                       0
# Air temperature [K]        0
# Process temperature [K]    0
# Rotational speed [rpm]     0
# Torque [Nm]                0
# Tool wear [min]            0
# Target                     0
# Failure Type               0
# dtype: int64

# %%
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.set_style('darkgrid')
plt.rcParams['font.size']=14
plt.rcParams['figure.figsize']=(10,6)

# %%
df1.head(3)
# Out:
#    UDI Product ID Type  Air temperature [K]  Process temperature [K]  \
# 0    1     M14860    M                298.1                    308.6
# 1    2     L47181    L                298.2                    308.7
# 2    3     L47182    L                298.1                    308.5
#
#    Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target Failure Type
# 0                    1551         42.8                0       0   No Failure
# 1                    1408         46.3                3       0   No Failure
# 2                    1498         49.4                5       0   No Failure

# %%
fig=px.histogram(df1,x='Air temperature [K]',color='Failure Type',title='Air Temperature vs Failure type')
fig
# Out:
# <div>                            <div id="ec7d8a70-26a3-4a97-8cf6-27b81e115103" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ec7d8a70-26a3-4a97-8cf6-27b81e115103")) {                    Plotly.newPlot(                        "ec7d8a70-26a3-4a97-8cf6-27b81e115103",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Failure Type=No Failure<br>Air temperature [K]=%{x}<br>count=%{y}<extra></extra>","legendgroup":"No Failure","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No Failure","offsetgroup":"No Failure","orientation":"v","showlegend":true,"x":[298.1,298.2,298.1,298.2,298.2,298.1,298.1,298.1,298.3,298.5,298.4,298.6,298.6,298.6,298.6,298.6,298.6,298.7,298.8,298.9,298.9,298.8,298.9,299.0,299.0,299.0,299.1
# ...

# %% [markdown]
# ##### Power failure and overstrain failure can occur at any temperature but as the tempersture increases above 300k tool wear failure and heat dissipation failure is more

# %%
fig=px.histogram(df1,x='Process temperature [K]',color='Failure Type',title='Process Temperature vs Failure type')
fig
# Out:
# <div>                            <div id="a7cb0cdc-0bfd-4a40-810a-b790a0de9dd5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a7cb0cdc-0bfd-4a40-810a-b790a0de9dd5")) {                    Plotly.newPlot(                        "a7cb0cdc-0bfd-4a40-810a-b790a0de9dd5",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Failure Type=No Failure<br>Process temperature [K]=%{x}<br>count=%{y}<extra></extra>","legendgroup":"No Failure","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No Failure","offsetgroup":"No Failure","orientation":"v","showlegend":true,"x":[308.6,308.7,308.5,308.6,308.7,308.6,308.6,308.6,308.7,309.0,308.9,309.1,309.1,309.2,309.2,309.2,309.2,309.2,309.2,309.3,309.3,309.3,309.3,309.4,309.4,309.5,3
# ...

# %%
df1.head(3)
# Out:
#    UDI Product ID Type  Air temperature [K]  Process temperature [K]  \
# 0    1     M14860    M                298.1                    308.6
# 1    2     L47181    L                298.2                    308.7
# 2    3     L47182    L                298.1                    308.5
#
#    Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target Failure Type
# 0                    1551         42.8                0       0   No Failure
# 1                    1408         46.3                3       0   No Failure
# 2                    1498         49.4                5       0   No Failure

# %%
fig=px.scatter(df1,x='Air temperature [K]',y='Process temperature [K]',color='Failure Type')
fig
# Out:
# <div>                            <div id="6d46f749-f1a8-492f-8341-8e0b58895c2f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6d46f749-f1a8-492f-8341-8e0b58895c2f")) {                    Plotly.newPlot(                        "6d46f749-f1a8-492f-8341-8e0b58895c2f",                        [{"hovertemplate":"Failure Type=No Failure<br>Air temperature [K]=%{x}<br>Process temperature [K]=%{y}<extra></extra>","legendgroup":"No Failure","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"No Failure","showlegend":true,"x":[298.1,298.2,298.1,298.2,298.2,298.1,298.1,298.1,298.3,298.5,298.4,298.6,298.6,298.6,298.6,298.6,298.6,298.7,298.8,298.9,298.9,298.8,298.9,299.0,299.0,299.0,299.1,299.1,299.1,299.0,299.1,299.0,299.0,298.9,298.8,298.8
# ...

# %%
fig=px.histogram(df1.sample(5000),x='Rotational speed [rpm]',color='Failure Type',title='Rotational speed vs Failure type')
fig
# Out:
# <div>                            <div id="81f474cd-97bb-40cf-bf3f-07673a5406e5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("81f474cd-97bb-40cf-bf3f-07673a5406e5")) {                    Plotly.newPlot(                        "81f474cd-97bb-40cf-bf3f-07673a5406e5",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Failure Type=No Failure<br>Rotational speed [rpm]=%{x}<br>count=%{y}<extra></extra>","legendgroup":"No Failure","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No Failure","offsetgroup":"No Failure","orientation":"v","showlegend":true,"x":[1790,1547,1408,1431,1372,1858,1735,1711,1433,1500,1496,1421,1394,1462,1345,1716,1291,1424,1500,1826,1416,1563,1366,1545,1811,1436,1569,1465,1428,1541,1514,168
# ...

# %%
fig=px.histogram(df1.sample(5000),x='Torque [Nm]',color='Failure Type',title='Tool wear [min]')
fig
# Out:
# <div>                            <div id="cffa2eba-c614-4376-b7a9-7a03da8342a1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cffa2eba-c614-4376-b7a9-7a03da8342a1")) {                    Plotly.newPlot(                        "cffa2eba-c614-4376-b7a9-7a03da8342a1",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Failure Type=No Failure<br>Torque [Nm]=%{x}<br>count=%{y}<extra></extra>","legendgroup":"No Failure","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No Failure","offsetgroup":"No Failure","orientation":"v","showlegend":true,"x":[32.8,37.6,64.4,40.6,37.9,43.4,20.4,50.6,41.0,37.5,50.4,32.4,28.6,34.1,57.5,57.2,37.1,34.0,42.4,45.7,46.5,45.8,28.2,35.1,51.1,20.7,38.5,29.7,50.6,34.2,30.8,33.4,37.4,16.6
# ...

# %%
fig=px.scatter(df1,x='Rotational speed [rpm]',y='Torque [Nm]',color='Tool wear [min]')
fig
# Out:
# <div>                            <div id="4a334b10-206c-4684-8ad0-a8dfb07d2ea0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4a334b10-206c-4684-8ad0-a8dfb07d2ea0")) {                    Plotly.newPlot(                        "4a334b10-206c-4684-8ad0-a8dfb07d2ea0",                        [{"hovertemplate":"Rotational speed [rpm]=%{x}<br>Torque [Nm]=%{y}<br>Tool wear [min]=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[0,3,5,7,9,11,14,16,18,21,24,29,34,37,40,42,44,47,50,55,58,63,65,68,70,73,75,77,82,84,86,89,91,93,95,98,101,104,106,111,113,115,117,120,125,128,130,133,135,140,143,145,147,152,154,156,158,160,162,165,167,169,172,174,177,179,181,184,189,191,193,196,198,200,202,204,206,208,0,2,4,9,11,13,15,17,20,25,27,30,33,35,37,40
# ...

# %%
df1.columns
# Out:
# Index(['UDI', 'Product ID', 'Type', 'Air temperature [K]',
#        'Process temperature [K]', 'Rotational speed [rpm]', 'Torque [Nm]',
#        'Tool wear [min]', 'Target', 'Failure Type'],
#       dtype='object')

# %%
df1[df1['Target']!=0]
# Out:
#        UDI Product ID Type  Air temperature [K]  Process temperature [K]  \
# 50      51     L47230    L                298.9                    309.1
# 69      70     L47249    L                298.9                    309.0
# 77      78     L47257    L                298.8                    308.9
# 160    161     L47340    L                298.4                    308.2
# 161    162     L47341    L                298.3                    308.1
# ...    ...        ...  ...                  ...                      ...
# 9758  9759     L56938    L                298.6                    309.8
# 9764  9765     L56944    L                298.5                    309.5
# 9822  9823     L57002    L                298.5                    309.4
# 9830  9831     L57010    L                298.3                    309.3
# 9974  9975     L57154    L                298.6                    308.2
#
#       Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target  \
# ...

# %%
fig=px.histogram(df1.sample(5000),x='Tool wear [min]',color='Failure Type',title='Tool wear [min]')
fig
# Out:
# <div>                            <div id="f686b50c-a99b-490e-a2e4-fb8dcd21fc02" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f686b50c-a99b-490e-a2e4-fb8dcd21fc02")) {                    Plotly.newPlot(                        "f686b50c-a99b-490e-a2e4-fb8dcd21fc02",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Failure Type=No Failure<br>Tool wear [min]=%{x}<br>count=%{y}<extra></extra>","legendgroup":"No Failure","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No Failure","offsetgroup":"No Failure","orientation":"v","showlegend":true,"x":[79,121,14,50,115,116,68,86,142,76,0,88,169,81,197,131,0,213,121,156,194,119,172,65,174,52,83,69,144,43,113,188,137,84,9,74,4,70,202,193,105,146,133,152,160,166,52,59
# ...

# %%
df1.Type.unique()
# Out:
# array(['M', 'L', 'H'], dtype=object)

# %%
df1.head(3)
# Out:
#    UDI Product ID Type  Air temperature [K]  Process temperature [K]  \
# 0    1     M14860    M                298.1                    308.6
# 1    2     L47181    L                298.2                    308.7
# 2    3     L47182    L                298.1                    308.5
#
#    Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target Failure Type
# 0                    1551         42.8                0       0   No Failure
# 1                    1408         46.3                3       0   No Failure
# 2                    1498         49.4                5       0   No Failure

# %%
df2=df1.drop(['UDI','Product ID'],axis='columns')
df2.head(2)
# Out:
#   Type  Air temperature [K]  Process temperature [K]  Rotational speed [rpm]  \
# 0    M                298.1                    308.6                    1551
# 1    L                298.2                    308.7                    1408
#
#    Torque [Nm]  Tool wear [min]  Target Failure Type
# 0         42.8                0       0   No Failure
# 1         46.3                3       0   No Failure

# %%
x1=df2.drop(['Target','Failure Type'],axis='columns')
y=df2[['Target']]
x1.head(3)
# Out:
#   Type  Air temperature [K]  Process temperature [K]  Rotational speed [rpm]  \
# 0    M                298.1                    308.6                    1551
# 1    L                298.2                    308.7                    1408
# 2    L                298.1                    308.5                    1498
#
#    Torque [Nm]  Tool wear [min]
# 0         42.8                0
# 1         46.3                3
# 2         49.4                5

# %%
x=pd.get_dummies(x1,drop_first=True)
dummy.head(3)
# Out:
#    Air temperature [K]  Process temperature [K]  Rotational speed [rpm]  \
# 0                298.1                    308.6                    1551
# 1                298.2                    308.7                    1408
# 2                298.1                    308.5                    1498
#
#    Torque [Nm]  Tool wear [min]  Type_L  Type_M
# 0         42.8                0       0       1
# 1         46.3                3       1       0
# 2         49.4                5       1       0

# %%
y=pd.get_dummies(y,drop_first=True)
y
# Out:
#       Target
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ...      ...
# 9995       0
# 9996       0
# 9997       0
# 9998       0
# 9999       0
#
# [10000 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.2)
x_train.shape
# Out:
# (8000, 7)

# %%
x_test.shape
# Out:
# (2000, 7)

# %%
from sklearn.svm import SVC
model=SVC()
model.fit(x_train,y_train)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning:
#
# A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# SVC()

# %%
model.score(x_train,y_train)
# Out:
# 0.966625

# %%
model.score(x_test,y_test)
# Out:
# 0.9655

# %%
pred=model.predict(x_test)
pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
model.predict([[298.1,308.6,1551,42.8,0,0,1]])
# Out:
# array([0], dtype=int64)
